# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = 'data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head(8)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
# None

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.describe(include=['object', 'bool'])
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %%
mask=data['Year']==1972
maskMedal=data['Medal']=='Bronze'

# %%
data['Sex'][mask].value_counts(normalize=True)
# Out:
# M    0.571525
# F    0.428475
# Name: Sex, dtype: float64

# %%
data[maskMedal].sort_values(by='Age', ascending=False).head()
# Out:
#             ID                     Name Sex   Age  Height  Weight        Team  \
# 60009    30731               Jozu Dupon   M  72.0     NaN     NaN     Belgium
# 150756   75648   Charles William Martin   M  71.0     NaN     NaN  Crabe II-4
# 89338    45286  Letitia Marion Hamilton   F  69.0     NaN     NaN     Ireland
# 154806   77710     Robert Tait McKenzie   M  65.0     NaN     NaN      Canada
# 233391  117046        Oscar Gomer Swahn   M  64.0     NaN     NaN      Sweden
#
#         NOC        Games  Year  Season         City             Sport  \
# 60009   BEL  1936 Summer  1936  Summer       Berlin  Art Competitions
# 150756  FRA  1900 Summer  1900  Summer        Paris           Sailing
# 89338   IRL  1948 Summer  1948  Summer       London  Art Competitions
# 154806  CAN  1932 Summer  1932  Summer  Los Angeles  Art Competitions
# 233391  SWE  1912 Summer  1912  Summer    Stockholm          Shooting
#
#                                                     Event   Medal
# 60009          Art Competitions Mixed Sculpturing, Medals  Bronze
# 150756                            Sailing Mixed 0.5-1 Ton  Bronze
# 89338          Art Competitions Mixed Painting, Paintings  Bronze
# 154806  Art Competitions Mixed Sculpturing, Medals And...  Bronze
# 233391         Shooting Men's Running Target, Double Shot  Bronze

# %%
data[mask].sort_values(by=['Year', 'Sex'], ascending=[True, True]).head()
# Out:
#           ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 84361  42835  Werner Grieshofer   M  12.0   170.0    48.0  Austria  AUT
# 11209   6129    Eleni Avlonitou   F  13.0   165.0    54.0   Greece  GRE
# 11210   6129    Eleni Avlonitou   F  13.0   165.0    54.0   Greece  GRE
# 11211   6129    Eleni Avlonitou   F  13.0   165.0    54.0   Greece  GRE
# 11212   6129    Eleni Avlonitou   F  13.0   165.0    54.0   Greece  GRE
#
#              Games  Year  Season    City     Sport  \
# 84361  1972 Summer  1972  Summer  Munich    Rowing
# 11209  1972 Summer  1972  Summer  Munich  Swimming
# 11210  1972 Summer  1972  Summer  Munich  Swimming
# 11211  1972 Summer  1972  Summer  Munich  Swimming
# 11212  1972 Summer  1972  Summer  Munich  Swimming
#
#                                                Event Medal
# 84361                       Rowing Men's Coxed Pairs   NaN
# 11209          Swimming Women's 400 metres Freestyle   NaN
# 11210          Swimming Women's 800 metres Freestyle   NaN
# 11211  Swimming Women's 200 metres Individual Medley   NaN
# 11212  Swimming Women's 400 metres Individual Medley   NaN

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12 !

# %%
# You code here
mask=data['Year']==1992
data[mask].sort_values(by=['Age', 'Sex'], ascending=[True, True]).head(2)
#11 and 12 y.o.
# Out:
#            ID                             Name Sex   Age  Height  Weight  \
# 73461   37333  Carlos Bienvenido Front Barrera   M  11.0     NaN     NaN
# 120233  60854                       Judit Kiss   F  12.0   171.0    57.0
#
#            Team  NOC        Games  Year  Season       City     Sport  \
# 73461     Spain  ESP  1992 Summer  1992  Summer  Barcelona    Rowing
# 120233  Hungary  HUN  1992 Summer  1992  Summer  Barcelona  Swimming
#
#                                         Event Medal
# 73461               Rowing Men's Coxed Eights   NaN
# 120233  Swimming Women's 400 metres Freestyle   NaN

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5 !
# - 7.7

# %%
# You code here
maskYear=data['Year']==2012
df2012=data[maskYear].drop_duplicates(subset ="Name")
malePart2012=df2012[df2012['Sex']=='M']
malePart2012.shape
print('Males in 2012:'+ str(malePart2012.shape[0]) )
maleBasketPart2012=malePart2012[malePart2012['Sport']=='Basketball']
maleBasketPart2012.shape
print('Males in Basketball 2012:'+ str(maleBasketPart2012.shape[0]) )
print('Answer:'+str(round(maleBasketPart2012.shape[0]/malePart2012.shape[0]*100,2)))
# data[mask2 & mask].drop_duplicates(subset ="Name", keep = False, inplace = True)
# Out:
# Males in 2012:5857
# Males in Basketball 2012:143
# Answer:2.44

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5 !
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
# You code here
maskYear=data['Year']==2000
df2012=data[maskYear].drop_duplicates(subset ="Name")
FemalePart2000=df2012[df2012['Sex']=='F']
FemalePart2000[FemalePart2000['Sport']=='Tennis'].agg([np.mean, np.std, np.min, np.max])['Height']
# Out:
# mean    171.806818
# std       6.563322
# amin    150.000000
# amax    191.000000
# Name: Height, dtype: float64

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton !
# - Boxing

# %%
# You code here
mask=data['Year']==2006
data[mask].sort_values(by='Weight',ascending=False).head(2)
# Out:
#           ID               Name Sex   Age  Height  Weight      Team  NOC  \
# 8102    4476  Patrick R. Antaki   M  41.0   185.0   127.0   Lebanon  LIB
# 38615  19867         Zdeno Chra   M  28.0   206.0   116.0  Slovakia  SVK
#
#              Games  Year  Season    City       Sport  \
# 8102   2006 Winter  2006  Winter  Torino    Skeleton
# 38615  2006 Winter  2006  Winter  Torino  Ice Hockey
#
#                              Event Medal
# 8102       Skeleton Men's Skeleton   NaN
# 38615  Ice Hockey Men's Ice Hockey   NaN

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2 !
# - 3

# %%
# You code here
data[data['Name']=='John Aalberg'].drop_duplicates(subset ="Year")
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 18   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 18  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                        Event Medal
# 18  Cross Country Skiing Men's 10 kilometres   NaN
# 22  Cross Country Skiing Men's 10 kilometres   NaN

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2 !
# - 3

# %%
# You code here
mask=data['Year']==2008
data2008=data[mask]
data2008[(data2008['Team']=='Switzerland') & (data2008['Sport']=='Tennis')].dropna()
# Out:
#             ID                Name Sex   Age  Height  Weight         Team  \
# 67290    34396       Roger Federer   M  26.0   185.0    80.0  Switzerland
# 257672  129042  Stanislas Wawrinka   M  23.0   183.0    79.0  Switzerland
#
#         NOC        Games  Year  Season     City   Sport                 Event  \
# 67290   SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
# 257672  SUI  2008 Summer  2008  Summer  Beijing  Tennis  Tennis Men's Doubles
#
#        Medal
# 67290   Gold
# 257672  Gold

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes
# - No

# %%
# You code here
mask=data['Year']==2016
dataYear=data[mask]
itMedN=dataYear[(dataYear['Team']=='Italy')].dropna().shape[0]
spMedN=dataYear[(dataYear['Team']=='Spain')].dropna().shape[0]
print('Italy Medals : '+str(itMedN))
print('Spain Medals : '+str(spMedN))
# Out:
# Italy Medals : 70
# Spain Medals : 43

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35)6008 correspondingly   !
# - [45-55] and [15-25)4411 correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
# You code here
mask=data['Year']==2016
dataYear=data[mask].drop_duplicates(subset ="Name")
ranges = pd.cut(dataYear['Age'], [0,14.5,24.5,34.5,44.5,55,100])
dataYear.groupby(ranges)['Age'].agg(['count', 'sum'])
#dataYear['Survived'].groupby(
# dataYear.groupby(pd.qcut(dataYear['Age'],10)).count()
# Out:
#                count       sum
# Age
# (0.0, 14.5]       10     138.0
# (14.5, 24.5]    4411   95218.0
# (24.5, 34.5]    6008  170367.0
# (34.5, 44.5]     653   24440.0
# (44.5, 55.0]      84    4119.0
# (55.0, 100.0]      8     473.0

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes !
# - Yes, No
# - No, Yes
# - No, No

# %%
# You code here
summerOlyMask=data['Games'].str.find('Summer')>0
# data[summerOlyMask].groupby(['Games']).describe(include=['object', 'bool'])['City']
data[(data['Season']=='Summer') & (data['City']=='Atlanta')].drop_duplicates(subset ="Year")
data[(data['Season']=='Winter') & (data['City']=='Squaw Valley')].drop_duplicates(subset ="Year")
# Out:
#     ID              Name Sex   Age  Height  Weight    Team  NOC        Games  \
# 83  24  Nils Egil Aaness   M  24.0     NaN     NaN  Norway  NOR  1960 Winter
#
#     Year  Season          City          Sport                           Event  \
# 83  1960  Winter  Squaw Valley  Speed Skating  Speed Skating Men's 500 metres
#
#    Medal
# 83   NaN

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15 !
# - 27

# %%
# You code here
mask=data['Year']==1896
dataYear=data[mask].drop_duplicates(subset ="Sport").shape
print('Sport disciplines at 1896: '+str(dataYear[0]))
dataYear1=data[data['Year']==2002].drop_duplicates(subset ="Sport").shape
print('Sport disciplines at 2002: '+str(dataYear1[0]))
# Out:
# Sport disciplines at 1896: 9
# Sport disciplines at 2002: 15

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
